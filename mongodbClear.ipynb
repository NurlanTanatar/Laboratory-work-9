# %%
import pymongo
myclient = pymongo.MongoClient("mongodb+srv://Nolan:5002@clusternolan-tlcfu.mongodb.net/test")
mydb = myclient["pp2"]
mycol = mydb["customers"]

# %%
x = mycol.delete_many({})
x

# %%
x.deleted_count
# Out:
# 27
